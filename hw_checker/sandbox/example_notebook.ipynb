# %%
import os

# %%
print(123 + 1231)

# %%
os.listdir() # вывод без принта

# %% [markdown]
# ## MARKDOWN ячейка

# %%
a = 123 / 0 # ячейка с ошибкой

# %%
print('Hello, world!')

# %%
from collections import ChainMap

chm = ChainMap({'a': 1, 'b': 2}, {'b': 3, 'c': 4})

# %%
b = 123
